# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = {}
with open("environment/train_values.csv", "r") as f:
    category = f.readline().strip().split(",")
    for s in category:
        data[s] = []
    for l in f:
        l = l.strip().split(",")
        for i,s in enumerate(l):
            data[category[i]].append(float(l[i]))

# %%
for s in category:
    plt.figure()
    plt.title(s)
    if s in ["episode-return"," value-loss"," policy-loss"]:

        new_data = np.array(data[s])
        new_data = new_data - min(0,np.min(new_data))
        plt.plot(new_data)
        plt.yscale('log')
    else:
        plt.plot(data[s])

plt.show()
# Out:
# episode-return True
#  value-loss True
#  policy-loss True
#  old-approx-kl False
#  approx-kl False
#  clip-fraction False
#  explained-variance False
